# %%
#기본 세팅
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
from google.colab import files
uploaded = files.upload() # 파일 업로드 

img = cv2.imread('./lena.png')
# Out:
#      <input type="file" id="files-71856476-8237-4870-a43f-58fd2fd8af4d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-71856476-8237-4870-a43f-58fd2fd8af4d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lena.png to lena.png

# %%
# cv2.fastNlMeansDenoisingColored() 컬러이미지로부터 잡음제거
dst = cv2.fastNlMeansDenoisingColored(img,None,10,10,7,21)

# %%
plt.subplot(121),plt.imshow(img)
plt.subplot(122),plt.imshow(dst)
plt.show()
